# %% [markdown]
# # Etapa de preparação e processamento dos dados

# %%
import pandas as pd

# %%
# lendo os arquivos csv
df1 = pd.read_csv('dados/dados-brasileirao.csv')
df2 = pd.read_csv('dados/brasileirao_odds.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0 serie  temporada            estadio         cidade estado  \
# 0           0     A       2012           Pacaembu      Sao Paulo     SP
# 1           1     A       2012     Ilha do Retiro         Recife     PE
# 2           2     A       2012  Orlando Scarpelli  Florianopolis     SC
# 3           3     A       2012   Moisés Lucarelli       Campinas     SP
# 4           4     A       2012           Pacaembu      Sao Paulo     SP
#
#   dia_semana  dia_numero     mes   ano   hora          mandante  \
# 0     Sábado          19   Maio   2012  18:30    Palmeiras - SP
# 1     Sábado          19   Maio   2012  18:30        Sport - PE
# 2     Sábado          19   Maio   2012  21:00  Figueirense - SC
# 3    Domingo          20   Maio   2012  16:00  Ponte Preta - SP
# 4    Domingo          20   Maio   2012  16:00  Corinthians - SP
#
#          visitante  gol_mandante  gol_visitante  vitoria_mandante  \
# 0  Portuguesa - SP             1              1                 0
# 1    Flamengo - RJ             1              1                 0
# 2     Náutico - PE             2              1                 1
# 3    Atlético - MG             0              1                 0
# 4  Fluminense - RJ             0              1                 0
#
#    vitoria_visitante  jogo_empatado  ponto_mandante  ponto_visitante
# 0                  0              1               1                1
# 1                  0              1               1                1
# 2                  0              0               3                0
# 3                  1              0               0                3
# 4                  1              0               0                3

# %%
# pegando dados somente de 2021, 2022, 2023 de df1 
df_cbf = df1[df1['temporada'].isin([2021, 2022, 2023])].reset_index(drop=True)


df_cbf.head()
# Out:
#    Unnamed: 0 serie  temporada         estadio          cidade estado  \
# 0        3419     A       2021  Arena Pantanal          Cuiaba     MT
# 1        3420     A       2021         Pituaçu        Salvador     BA
# 2        3421     A       2021         Morumbi       Sao Paulo     SP
# 3        3422     A       2021        Mineirão  Belo Horizonte     MG
# 4        3423     A       2021        Maracanã  Rio de Janeiro     RJ
#
#   dia_semana  dia_numero     mes   ano   hora               mandante  \
# 0     Sábado          29   Maio   2021  19:00            Cuiabá - MT
# 1     Sábado          29   Maio   2021  20:00             Bahia - BA
# 2     Sábado          29   Maio   2021  21:00         São Paulo - SP
# 3    Domingo          30   Maio   2021  11:00  Atlético Mineiro - MG
# 4    Domingo          30   Maio   2021  16:00          Flamengo - RJ
#
#          visitante  gol_mandante  gol_visitante  vitoria_mandante  \
# 0   Juventude - RS             2              2                 0
# 1      Santos - SP             3              0                 1
# 2  Fluminense - RJ             0              0                 0
# 3   Fortaleza - CE             1              2                 0
# 4   Palmeiras - SP             1              0                 1
#
#    vitoria_visitante  jogo_empatado  ponto_mandante  ponto_visitante
# 0                  0              1               1                1
# 1                  0              0               3                0
# 2                  0              1               1                1
# 3                  1              0               0                3
# 4                  0              0               3                0

# %%
# Ajustar os nomes das colunas de df2 para corresponderem aos de df_cbf para a fusão
df2.rename(columns={'Year': 'ano', 'Time': 'hora', 'Home Team': 'mandante', 
                    'Away Team': 'visitante', 'Home Score': 'gol_mandante', 
                    'Away Score': 'gol_visitante'}, inplace=True)

df2.head()
# Out:
#     ano   hora     mandante  gol_mandante  gol_visitante       visitante  \
# 0  2021  21:30   America MG             2              0       Sao Paulo
# 1  2021  21:30  Atletico GO             2              0     Flamengo RJ
# 2  2021  21:30   Bragantino             1              0   Internacional
# 3  2021  21:30    Juventude             1              0     Corinthians
# 4  2021  21:30   Fluminense             3              0  Chapecoense-SC
#
#    Odd 1  Odd X  Odd 2
# 0   2.00   3.32   3.98
# 1   1.72   3.89   4.57
# 2   1.90   3.65   4.01
# 3   2.25   3.10   3.52
# 4   1.19   6.62  15.82

# %%
# listando os times únicos de df1
times = df_cbf['mandante'].unique()

print(times)
# Out:
# ['Cuiabá - MT' 'Bahia - BA' 'São Paulo - SP' 'Atlético Mineiro - MG'
#  'Flamengo - RJ' 'Ceará - CE' 'Chapecoense - SC' 'Corinthians - SP'
#  'Athletico Paranaense - PR' 'Internacional - RS' 'Atlético - GO'
#  'Red Bull Bragantino - SP' 'Santos - SP' 'Fluminense - RJ' 'America - MG'
#  'Fortaleza - CE' 'Palmeiras - SP' 'Juventude - RS' 'Sport - PE'
#  'Grêmio - RS' 'Coritiba - PR' 'Botafogo - RJ' 'Avaí - SC' 'Goiás - GO'
#  'América Fc Saf - MG' 'Cuiabá Saf - MT' 'América Saf - MG'
#  'Atlético Mineiro Saf - MG' 'Cruzeiro Saf - MG'
#  'Vasco da Gama S.a.f. - RJ' 'Coritiba S.a.f. - PR']

# %%
# listando os times únicos de df2
times_odds = df2['Home Team'].unique()

print(times_odds)
# Out:
# ['America MG' 'Atletico GO' 'Bragantino' 'Juventude' 'Fluminense'
#  'Fortaleza' 'Gremio' 'Palmeiras' 'Santos' 'Sport Recife' 'Chapecoense-SC'
#  'Cuiaba' 'Flamengo RJ' 'Internacional' 'Athletico-PR' 'Sao Paulo' 'Ceara'
#  'Atletico-MG' 'Bahia' 'Corinthians' 'Goias' 'Botafogo RJ' 'Avai'
#  'Coritiba' 'Cruzeiro' 'Vasco']

# %%
# Dicionário de mapeamento baseado nas listas fornecidas
name_mapping = {
    'America MG': 'América Fc Saf - MG',
    'Atletico GO': 'Atlético - GO',
    'Bragantino': 'Red Bull Bragantino - SP',
    'Juventude': 'Juventude - RS',
    'Fluminense': 'Fluminense - RJ',
    'Fortaleza': 'Fortaleza - CE',
    'Gremio': 'Grêmio - RS',
    'Palmeiras': 'Palmeiras - SP',
    'Santos': 'Santos - SP',
    'Sport Recife': 'Sport - PE',
    'Chapecoense-SC': 'Chapecoense - SC',
    'Cuiaba': 'Cuiabá Saf - MT',
    'Flamengo RJ': 'Flamengo - RJ',
    'Internacional': 'Internacional - RS',
    'Athletico-PR': 'Athletico Paranaense - PR',
    'Sao Paulo': 'São Paulo - SP',
    'Ceara': 'Ceará - CE',
    'Atletico-MG': 'Atlético Mineiro Saf - MG',
    'Bahia': 'Bahia - BA',
    'Corinthians': 'Corinthians - SP',
    'Goias': 'Goiás - GO',
    'Botafogo RJ': 'Botafogo - RJ',
    'Avai': 'Avaí - SC',
    'Coritiba': 'Coritiba - PR',
    'Cruzeiro': 'Cruzeiro Saf - MG',
    'Vasco': 'Vasco da Gama S.a.f. - RJ'
}

# Aplicar o mapeamento para as colunas 'mandante' e 'visitante' no df2
df2['mandante'] = df2['mandante'].map(name_mapping)
df2['visitante'] = df2['visitante'].map(name_mapping)

# Verifique se há alguma entrada que não foi mapeada corretamente
print(df2[df2['mandante'].isnull() | df2['visitante'].isnull()])

df2.head()
# Out:
# Empty DataFrame
# Columns: [ano, hora, mandante, gol_mandante, gol_visitante, visitante, Odd 1, Odd X, Odd 2]
# Index: []
#     ano   hora                  mandante  gol_mandante  gol_visitante  \
# 0  2021  21:30       América Fc Saf - MG             2              0
# 1  2021  21:30             Atlético - GO             2              0
# 2  2021  21:30  Red Bull Bragantino - SP             1              0
# 3  2021  21:30            Juventude - RS             1              0
# 4  2021  21:30           Fluminense - RJ             3              0
#
#             visitante  Odd 1  Odd X  Odd 2
# 0      São Paulo - SP   2.00   3.32   3.98
# 1       Flamengo - RJ   1.72   3.89   4.57
# 2  Internacional - RS   1.90   3.65   4.01
# 3    Corinthians - SP   2.25   3.10   3.52
# 4    Chapecoense - SC   1.19   6.62  15.82

# %%
df_merged = pd.merge(df_cbf, df2, on=['ano', 'hora', 'mandante', 'visitante'], how='inner')

df_merged.head()
# Out:
#    Unnamed: 0 serie  temporada          estadio        cidade estado  \
# 0        3438     A       2021  Arena do Grêmio  Porto Alegre     RS
# 1        3438     A       2021  Arena do Grêmio  Porto Alegre     RS
# 2        3438     A       2021  Arena do Grêmio  Porto Alegre     RS
# 3        3438     A       2021  Arena do Grêmio  Porto Alegre     RS
# 4        3438     A       2021  Arena do Grêmio  Porto Alegre     RS
#
#   dia_semana  dia_numero         mes   ano  ... vitoria_mandante  \
# 0      Terça          23   Novembro   2021  ...                0
# 1      Terça          23   Novembro   2021  ...                0
# 2      Terça          23   Novembro   2021  ...                0
# 3      Terça          23   Novembro   2021  ...                0
# 4      Terça          23   Novembro   2021  ...                0
#
#   vitoria_visitante jogo_empatado  ponto_mandante  ponto_visitante  \
# 0                 0             1               1                1
# 1                 0             1               1                1
# 2                 0             1               1                1
# 3                 0             1               1                1
# 4                 0             1               1                1
#
#    gol_mandante_y  gol_visitante_y  Odd 1  Odd X  Odd 2
# 0               2                2   2.03   3.56   3.55
# 1               2                2   2.03   3.56   3.55
# 2               2                2   2.03   3.56   3.55
# 3               2                2   2.03   3.56   3.55
# 4               2                2   2.03   3.56   3.55
#
# [5 rows x 25 columns]

# %%
# verifica se existe algum valor nulo ema todas as colunas
print(df_merged.isnull().sum())
# Out:
# Unnamed: 0           0
# serie                0
# temporada            0
# estadio              0
# cidade               0
# estado               0
# dia_semana           0
# dia_numero           0
# mes                  0
# ano                  0
# hora                 0
# mandante             0
# visitante            0
# gol_mandante_x       0
# gol_visitante_x      0
# vitoria_mandante     0
# vitoria_visitante    0
# jogo_empatado        0
# ponto_mandante       0
# ponto_visitante      0
# gol_mandante_y       0
# gol_visitante_y      0
# Odd 1                0
# Odd X                0
# Odd 2                0
# dtype: int64

# %%
# contando numero de linhas para o ano 2021
print(df_merged[df_merged['ano'] == 2021].shape[0])
# Out:
# 272

# %%
# contando numero de linhas para o ano 2022
print(df_merged[df_merged['ano'] == 2022].shape[0])
# Out:
# 320

# %%
# contando numero de linhas para o ano 2023
print(df_merged[df_merged['ano'] == 2023].shape[0])
# Out:
# 328

# %%
# salvando o dataframe em um arquivo csv
df_merged.to_csv('dados/brasileirao_2021_2023.csv', index=False)
